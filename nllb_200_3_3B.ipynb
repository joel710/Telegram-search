# %% [markdown]
# <a href="https://colab.research.google.com/github/joel710/Telegram-search/blob/main/nllb_200_3_3B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 86.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.56.2
#     Uninstalling transformers-4.56.2:
#       Successfully uninstalled transformers-4.56.2
# ...

# %%
# Translate French to Ewe
french_text = "Bonjour, comment ça va ?"
translated_text = pipe(french_text, src_lang="fra_Latn", tgt_lang="ewe_Latn")

print(f"French text: {french_text}")
print(f"Translated to Ewe: {translated_text[0]['translation_text']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3468326510.py in <cell line: 0>()
#       1 # Translate French to Ewe
#       2 french_text = "Bonjour, comment ça va ?"
# ----> 3 translated_text = pipe(french_text, src_lang="fra_Latn", tgt_lang="ewe_Latn")
#       4
#       5 print(f"French text: {french_text}")
#
# NameError: name 'pipe' is not defined

# %%
from transformers import pipeline

pipe = pipeline("translation", model="facebook/nllb-200-3.3B")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/808 [00:00<?, ?B/s]
# pytorch_model.bin.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/6.93G [00:00<?, ?B/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/8.55G [00:00<?, ?B/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/2.10G [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# ...

# %%
french_text = "je suis professeur a l'ecole "
translated_text = pipe(french_text, src_lang="fra_Latn", tgt_lang="ewe_Latn")

print(f"French text: {french_text}")
print(f"Translated to Ewe: {translated_text[0]['translation_text']}")
# Out:
# French text: je suis professeur a l'ecole
# Translated to Ewe: Mefiaa nu le suku.

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/facebook/nllb-200-3.3B
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/facebook/nllb-200-3.3B)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("translation", model="facebook/nllb-200-3.3B")

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-3.3B")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-3.3B")
